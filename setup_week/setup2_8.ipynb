# %%
# 2.8.1

i = 0
while i <= 20:
    if i % 5 == 0 and i != 0:
        print(i)
    i += 1
# Out:
# 5
# 10
# 15
# 20

# %%
# 2.8.2

for i in range(5):
    for j in range(i+1):
        print(j+1, end='')
    print()
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %%
# 2.8.3

a = { 1: 'A', 3:'A', 5:'B' }

for k, v in a.items():
    print(f'{k}: {v}')
# Out:
# 1: A
# 3: A
# 5: B

# %%
# 2.8.4

a = [1, 2, 3]

for i in range(len(a)):
    a[i] = a[i] * 100
print(a)
# Out:
# [100, 200, 300]

# %%
# 2.8.5

m = [ 1, 2, 3, 4, 5 ]
total = 0
for num in m:
 	total = total + num
print(total)
# Out:
# 15
