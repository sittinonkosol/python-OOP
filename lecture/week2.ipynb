# %% [markdown]
# # oop - object oriented programming
# procedural - การเขียนเชิงกระบวนการ ยากต่อการบำรุงรักษา เพราะ code ถูกเขียนผสมกัน<br>
# object oriented - การเขียนโปรแกรมเชิงวัตถุ งานต่อการบำรุงรักษา เพราะ ถูกเขียนแยกสัดส่วนกัน

# %%
class This_is_calss:
    def method(*parameters):
        # attribute
        pass

class User:
    def accounting():
        # คิดเงิน
        pass
    def programer():
        # เขียนโปรแกรม
        pass
    def sale():
        # ขายของ
        pass

# %%
class calculator:
    def add(i,j):
        return i + j

    def mul(i, j):
        return i * j
    
i_ger = calculator
print(i_ger.add(3,5))
print(i_ger.mul(2,5))
# Out:
# 8
# 10
